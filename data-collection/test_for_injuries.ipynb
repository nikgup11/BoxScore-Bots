# %%
from nbainjuries import injury
from datetime import datetime

# %%
output = injury.get_reportdata(datetime(year=2025, month=4, day=25, hour=17, minute=30), return_df=True)
output.head(10)
# Out:
# Validated Injury-Report_2025-04-25_05PM.
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 output = injury.get_reportdata(datetime(year=2025, month=4, day=25, hour=17, minute=30), return_df=True)
#       2 output.head(10)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/nbainjuries/injury.py:43, in get_reportdata(timestamp, local, localdir, return_df, **kwargs)
#      41     return df_result if return_df else df_result.to_json(orient='records', index=False, indent=2, force_ascii=False)
#      42 else:
# ---> 43     df_result = _parser.extract_injrepurl(gen_url(timestamp), area_headpg=area_bounds,
#      44                                           cols_headpg=col_bounds,
#      45                                           headers=headerparam)
# ...
