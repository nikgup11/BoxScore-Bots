# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./output_data/binary_player_prediction.csv')

# %%
df.sort_values(by='confidence', ascending=False, inplace=True)
df.head(10)
# Out:
#     personId firstName     lastName                 Date prediction  \
# 47   1629731      Dean         Wade  2025-12-25 12:00:00      UNDER
# 32   1630230      Naji     Marshall  2025-12-25 17:00:00      UNDER
# 19   1629655    Daniel      Gafford  2025-12-25 17:00:00       OVER
# 13   1628978     Donte   DiVincenzo  2025-12-25 22:30:00      UNDER
# 12    203076   Anthony        Davis  2025-12-25 17:00:00       OVER
# 11    201939   Stephen        Curry  2025-12-25 17:00:00       OVER
# 45    202685     Jonas  Valanciunas  2025-12-25 22:30:00       OVER
# 39   1630559    Austin       Reaves  2025-12-25 20:00:00      UNDER
# 27    201143        Al      Horford  2025-12-25 17:00:00       OVER
# 43    202691      Klay     Thompson  2025-12-25 17:00:00       OVER
#
#     over_prob  under_prob  over_under_line  confidence  test_accuracy  \
# 47   0.026353    0.973647              6.5    0.973647       1.000000
# 32   0.052949    0.947051             13.5    0.947051       0.600000
# 19   0.923902    0.076098              4.5    0.923902       0.857143
# 13   0.091582    0.908418             13.5    0.908418       0.846154
# 12   0.896290    0.103710             24.5    0.896290       0.733333
# 11   0.878399    0.121601             28.5    0.878399       0.515152
# 45   0.873101    0.126899              8.5    0.873101       0.562500
# 39   0.138831    0.861169             19.5    0.861169       0.750000
# 27   0.858795    0.141205              6.5    0.858795       0.804878
# 43   0.825903    0.174097             11.5    0.825903       0.727273
#
#    playerteamName opponentteamName
# 47      Cavaliers           Knicks
# 32      Mavericks         Warriors
# 19      Mavericks         Warriors
# 13   Timberwolves          Nuggets
# 12      Mavericks         Warriors
# 11       Warriors        Mavericks
# 45        Nuggets     Timberwolves
# 39         Lakers          Rockets
# 27       Warriors        Mavericks
# 43      Mavericks         Warriors
