# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./output_data/linear_player_prediction.csv')

# %%
average_mse = df['MSE'].mean()
median_mse = df['MSE'].median()
print('median MSE: ' + str(median_mse))
print('average MSE: ' + str(average_mse))
below_average_mse = df[(df['MSE'] < average_mse) & (df['predictedPoints'] > 10)]
below_median_mse = df[(df['MSE'] < median_mse) & (df['predictedPoints'] > 10)]
print('Players with below average MSE: ' + str(len(below_average_mse)))
print('Players with below median MSE: ' + str(len(below_median_mse)))
below_median_mse.sort_values(by=['MSE'], ascending=True, inplace=True)
below_median_mse.head(20)
# Out:
# median MSE: 45.31529998779297
# average MSE: 53.821332575109594
# Players with below average MSE: 87
# Players with below median MSE: 53
# /var/folders/g1/_2rdlxw515q70qzlwgwjx1bh0000gn/T/ipykernel_55227/668948684.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   below_median_mse.sort_values(by=['MSE'], ascending=True, inplace=True)
#      personId   firstName       lastName                 Date  \
# 448   1641717       Cason        Wallace  2025-12-23 20:30:00
# 285   1642862        Liam       McNeeley  2025-12-23 19:00:00
# 406   1642449        Tolu          Smith  2025-12-23 22:00:00
# 54    1628418      Thomas         Bryant  2025-12-23 19:30:00
# 204   1631218      Trayce  Jackson-Davis  2025-12-25 17:00:00
# 92    1642907      Cedric         Coward  2025-12-23 21:00:00
# 114    203083       Andre       Drummond  2025-12-23 19:00:00
# 66    1628976     Wendell     Carter Jr.  2025-12-23 22:00:00
# 58     203484  Kentavious  Caldwell-Pope  2025-12-23 21:00:00
# 78    1629651         Nic        Claxton  2025-12-23 19:00:00
# 185    201143          Al        Horford  2025-12-25 17:00:00
# 233   1630557       Corey        Kispert  2025-12-23 19:00:00
# 108   1641711      Gradey           Dick  2025-12-23 19:30:00
# 193   1642345         Oso       Ighodaro  2025-12-23 21:00:00
# 140   1630568        Luka          Garza  2025-12-26 19:00:00
# 119   1631106        Tari          Eason  2025-12-23 22:30:00
# 308   1631099      Keegan         Murray  2025-12-23 22:00:00
# 112   1629652    Luguentz           Dort  2025-12-23 20:30:00
# 59    1641739     Toumani         Camara  2025-12-23 22:00:00
# 148    203497        Rudy         Gobert  2025-12-23 20:00:00
#
#      predictedPoints        MSE
# 448        11.192666  12.833209
# 285        11.090903  13.891566
# 406        10.353412  17.077452
# 54         11.017711  20.357212
# 204        10.333783  20.700541
# 92         13.095012  22.341469
# 114        10.314698  27.108932
# 66         10.984019  27.933409
# 58         11.103159  28.325100
# 78         10.893115  28.819363
# 185        11.453850  29.187384
# 233        12.382989  29.733179
# 108        11.728883  31.364872
# 193        13.561093  31.744011
# 140        16.345881  32.642159
# 119        10.911828  34.384266
# 308        16.770994  34.641689
# 112        11.514264  34.657467
# 59         14.873277  34.724133
# 148        14.577035  34.977043

# %%
df.sort_values(by=['predictedPoints'], ascending=False, inplace=True)
df
# Out:
#      personId firstName lastName                 Date  predictedPoints  \
# 62    1642382   Branden  Carlson  2025-12-23 20:30:00        32.231827
# 52    1628973     Jalen  Brunson  2025-12-23 20:00:00        32.103275
# 274   1630178    Tyrese    Maxey  2025-12-23 19:00:00        30.944818
# 111   1629029      Luka   Doncic  2025-12-23 21:00:00        30.417320
# 117    201142     Kevin   Durant  2025-12-23 22:30:00        29.954212
# ..        ...       ...      ...                  ...              ...
# 150   1630692    Jordan  Goodwin  2025-12-23 21:00:00         0.000000
# 335   1629618     Jalen  Pickett  2025-12-23 20:00:00         0.000000
# 41    1631123   Jamaree   Bouyea  2025-12-23 21:00:00         0.000000
# 136   1642277    Johnny   Furphy  2025-12-23 19:30:00         0.000000
# 416   1643141    Jahmyl  Telfort  2025-12-23 22:30:00         0.000000
#
#             MSE
# 62    81.821541
# 52    82.324707
# 274  108.736870
# 111   64.744148
# 117   61.718063
# ..          ...
# 150   43.368378
# 335   29.603647
# 41    31.393183
# 136   57.073151
# 416    0.516647
#
# [489 rows x 6 columns]

# %%
df = df[df['predictedPoints'] > 10]
df.sort_values(by=['MSE'], ascending=True, inplace=True)
df
# Out:
# /var/folders/g1/_2rdlxw515q70qzlwgwjx1bh0000gn/T/ipykernel_55227/339412688.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by=['MSE'], ascending=True, inplace=True)
#      personId firstName       lastName                 Date  predictedPoints  \
# 448   1641717     Cason        Wallace  2025-12-23 20:30:00        11.192666
# 285   1642862      Liam       McNeeley  2025-12-23 19:00:00        11.090903
# 406   1642449      Tolu          Smith  2025-12-23 22:00:00        10.353412
# 54    1628418    Thomas         Bryant  2025-12-23 19:30:00        11.017711
# 204   1631218    Trayce  Jackson-Davis  2025-12-25 17:00:00        10.333783
# ..        ...       ...            ...                  ...              ...
# 225   1642357     David   Jones Garcia  2025-12-23 20:30:00        16.027138
# 129   1642847  Jeremiah          Fears  2025-12-23 19:30:00        10.717688
# 201   1631245   Quenton        Jackson  2025-12-23 19:30:00        10.063705
# 259   1631126     Caleb           Love  2025-12-23 22:00:00        10.314415
# 237   1642851       Kon       Knueppel  2025-12-23 19:00:00        15.427748
#
#             MSE
# 448   12.833209
# 285   13.891566
# 406   17.077452
# 54    20.357212
# 204   20.700541
# ..          ...
# 225  153.669998
# 129  158.481583
# 201  177.013245
# 259  185.764145
# 237  200.496048
#
# [201 rows x 6 columns]

# %%
plt.scatter(df['predictedPoints'], df['MSE'])
plt.xlabel('Predicted Points')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Predicted Points vs MSE')
for idx, row in df.iterrows():
    plt.annotate(f"{row['firstName']} {row['lastName']}", 
                 (row['predictedPoints'], row['MSE']),
                 fontsize=8, alpha=0.7)
plt.show()
