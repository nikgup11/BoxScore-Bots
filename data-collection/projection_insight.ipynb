# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./output_data/linear_player_prediction.csv')

# %%
average_mse = df['MSE'].mean()
median_mse = df['MSE'].median()
print('median MSE: ' + str(median_mse))
print('average MSE: ' + str(average_mse))
below_average_mse = df[(df['MSE'] < average_mse) & (df['predictedPoints'] > 10)]
below_median_mse = df[(df['MSE'] < median_mse) & (df['predictedPoints'] > 10)]
print('Players with below average MSE: ' + str(len(below_average_mse)))
print('Players with below median MSE: ' + str(len(below_median_mse)))
below_median_mse.sort_values(by=['MSE'], ascending=True, inplace=True)
below_median_mse.head(20)
# Out:
# median MSE: 43.51249313354492
# average MSE: 49.39354092530368
# Players with below average MSE: 75
# Players with below median MSE: 52
# /var/folders/g1/_2rdlxw515q70qzlwgwjx1bh0000gn/T/ipykernel_5306/668948684.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   below_median_mse.sort_values(by=['MSE'], ascending=True, inplace=True)
#      personId   firstName       lastName                 Date  \
# 57    1631232       Keion     Brooks Jr.  2025-12-23 19:30:00
# 522   1641717       Cason        Wallace  2025-12-23 20:30:00
# 200   1629637      Jaxson          Hayes  2025-12-23 21:00:00
# 63    1628418      Thomas         Bryant  2025-12-23 19:30:00
# 151   1627827      Dorian   Finney-Smith  2025-12-23 21:00:00
# 235   1631218      Trayce  Jackson-Davis  2025-12-25 17:00:00
# 304   1626168        Trey          Lyles  2025-12-23 22:00:00
# 424   1626196        Josh     Richardson  2025-12-23 19:30:00
# 78    1628976     Wendell     Carter Jr.  2025-12-23 22:00:00
# 130    203083       Andre       Drummond  2025-12-23 19:00:00
# 70     203484  Kentavious  Caldwell-Pope  2025-12-23 21:00:00
# 213    201143          Al        Horford  2025-12-25 17:00:00
# 93    1629651         Nic        Claxton  2025-12-23 19:00:00
# 271   1630557       Corey        Kispert  2025-12-23 19:00:00
# 222   1642345         Oso       Ighodaro  2025-12-23 21:00:00
# 121   1641711      Gradey           Dick  2025-12-23 19:30:00
# 314   1630231      Kenyon     Martin Jr.  2025-12-23 21:00:00
# 71    1641739     Toumani         Camara  2025-12-23 22:00:00
# 135   1642346        Ryan           Dunn  2025-12-23 21:00:00
# 346   1630558      Davion       Mitchell  2025-12-23 19:30:00
#
#      predictedPoints        MSE
# 57         36.864975   7.567438
# 522        11.267208  12.975214
# 200        10.503384  17.204779
# 63         10.327753  20.182459
# 151        10.169197  22.335232
# 235        10.514168  23.606215
# 304        11.607123  25.528496
# 424        10.180435  27.694407
# 78         11.729331  27.711926
# 130        10.139415  28.022503
# 70         11.370770  28.472258
# 213        11.834460  29.076988
# 93         10.772873  29.606983
# 271        13.194947  30.089525
# 222        12.378450  31.475058
# 121        11.079926  31.862316
# 314        10.298502  32.062241
# 71         14.511819  32.109112
# 135        14.431319  32.486935
# 346        11.820518  32.616611

# %%
df.sort_values(by=['predictedPoints'], ascending=False, inplace=True)
df
# Out:
#      personId firstName    lastName                 Date  predictedPoints  \
# 57    1631232     Keion  Brooks Jr.  2025-12-23 19:30:00        36.864975
# 62    1628973     Jalen     Brunson  2025-12-23 20:00:00        32.114979
# 318   1630178    Tyrese       Maxey  2025-12-23 19:00:00        30.683317
# 136    201142     Kevin      Durant  2025-12-23 22:30:00        30.003555
# 125   1629029      Luka      Doncic  2025-12-23 21:00:00        29.759743
# ..        ...       ...         ...                  ...              ...
# 531   1641817     Anton      Watson  2025-12-23 21:00:00         0.000000
# 173   1630692    Jordan     Goodwin  2025-12-23 21:00:00         0.000000
# 30    1641734     Emoni       Bates  2025-12-23 19:00:00         0.000000
# 176   1641789    Jazian     Gortman  2025-12-23 20:30:00         0.000000
# 397   1641854     Craig  Porter Jr.  2025-12-23 19:30:00         0.000000
#
#             MSE
# 57     7.567438
# 62    82.667938
# 318  108.691010
# 136   61.965824
# 125   64.265022
# ..          ...
# 531    7.201505
# 173   44.476646
# 30   119.571190
# 176   92.321075
# 397   42.117554
#
# [568 rows x 6 columns]

# %%
df = df[df['predictedPoints'] > 10]
df.sort_values(by=['MSE'], ascending=True, inplace=True)
df
# Out:
# /var/folders/g1/_2rdlxw515q70qzlwgwjx1bh0000gn/T/ipykernel_5306/339412688.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by=['MSE'], ascending=True, inplace=True)
#      personId firstName      lastName                 Date  predictedPoints  \
# 57    1631232     Keion    Brooks Jr.  2025-12-23 19:30:00        36.864975
# 522   1641717     Cason       Wallace  2025-12-23 20:30:00        11.267208
# 200   1629637    Jaxson         Hayes  2025-12-23 21:00:00        10.503384
# 63    1628418    Thomas        Bryant  2025-12-23 19:30:00        10.327753
# 151   1627827    Dorian  Finney-Smith  2025-12-23 21:00:00        10.169197
# ..        ...       ...           ...                  ...              ...
# 487   1630560       Cam        Thomas  2025-12-23 19:00:00        15.370373
# 140   1630162   Anthony       Edwards  2025-12-23 20:00:00        20.616409
# 164   1641718   Keyonte        George  2025-12-23 21:00:00        21.227928
# 515   1641774   Tristan      Vukcevic  2025-12-23 19:00:00        21.860985
# 312   1641798    Jaylen        Martin  2025-12-23 19:00:00        12.009731
#
#             MSE
# 57     7.567438
# 522   12.975214
# 200   17.204779
# 63    20.182459
# 151   22.335232
# ..          ...
# 487  108.976372
# 140  109.512825
# 164  134.050232
# 515  143.765060
# 312  149.802505
#
# [207 rows x 6 columns]

# %%
plt.scatter(df['predictedPoints'], df['MSE'])
plt.xlabel('Predicted Points')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Predicted Points vs MSE')
plt.show()
